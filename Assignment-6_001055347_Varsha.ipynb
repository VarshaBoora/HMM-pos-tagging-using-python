# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %%
def read_data(filename):
    """Read tagged sentence data"""
    with open(filename, 'r', encoding='utf-8', errors='ignore') as f:
        sentence_lines = [l.split("\n") for l in f.read().split("\n\n")]
    return OrderedDict(((s[0], Sentence(*zip(*[l.strip().split("\t")
                        for l in s[1:]]))) for s in sentence_lines if s[0]))

def read_tags(filename):
    """Read a list of word tag classes"""
    with open(filename, 'r') as f:
        tags = f.read().split("\n")
    return frozenset(tags)

Sentence = namedtuple("Sentence", "words tags")

# %%
tag = read_tags("english2.txt")
sentence1 = read_data("hindi2.txt")
sentence1
# Out:
# OrderedDict([('b100-5507',
#               Sentence(words=('इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है'), tags=('Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is'))),
#              ('b100-935',
#               Sentence(words=('इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है'), tags=('Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done'))),
#              ('b100-30614',
#               Sentence(words=('आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है', 'आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है', 'भैरव', 'का ', 'स्थान ', 'उत्तराखंड ', 'में ', 'क्षेत्रपाल ', 'अथवा ', 'भूमिदेव ', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'भैरव', 'का ', 'स्थान ', 'उत्तराखंड ', 'में ', 'क्षेत्रपाल ', 'अथवा ', 'भूमिदेव ', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'भैरव', 'का ', 'स्थान ', 'उत्तराखंड ', 'में ', 'क्षेत्रपाल ', 'अथवा ', 'भूमिदेव ', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है'), tags=('half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done', 'half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done', 'Bhairav', 'is', 'place', 'Uttarakhand', 'as', 'Kshetrapal', 'or', 'Bhoomidev', 'is', 'way', 'as', 'important', 'is', 'Bhairav', 'is', 'place', 'Uttarakhand', 'as', 'Kshetrapal', 'or', 'Bhoomidev', 'is', 'way', 'as', 'important', 'is', 'Bhairav', 'is', 'place', 'Uttarakhand', 'as', 'Kshetrapal', 'or', 'Bhoomidev', 'is', 'way', 'as', 'important', 'is'))),
#              ('b100-6250',
#               Sentence(words=('सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मेल ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('All', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'reconciliation', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'all', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-39560',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-3367',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मेल ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'All', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'reconciliation', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'all', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-3565',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-48585',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मेल ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'All', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'reconciliation', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'all', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-24517',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-22340',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है', 'भैरव', 'का ', 'स्थान ', 'उत्तराखंड ', 'में ', 'क्षेत्रपाल ', 'अथवा ', 'भूमिदेव ', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मेल ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done', 'Bhairav', 'is', 'place', 'Uttarakhand', 'as', 'Kshetrapal', 'or', 'Bhoomidev', 'is', 'way', 'as', 'important', 'is', 'All', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'reconciliation', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'all', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-27528',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-77722',
#               Sentence(words=('क्रिसमस', 'का', 'पर्व', 'या', 'त्योहार-पर्व', 'है', 'जिसे', 'न', 'केवल', 'ईसाई', 'धर्म', 'के', 'अनुयायी', 'समर्थक', 'ही', 'मनाते', 'है', 'अपितु', 'इसे', 'टी', 'विशव', 'के', 'प्रायः', 'सभी', 'धर्मो', 'ओर', 'सम्प्रदाय', 'के', 'लोग', 'मनाते', 'है', 'इस', 'प्रकार', 'बिना', 'भेदभाव', 'के', 'पूरे', 'विशव', 'में', 'मनाया', 'जाता', 'है', 'इसे', 'बिना', 'कोई'), tags=('Christmas', "'s", 'festival', 'or', 'festival', 'is', 'that', 'is not', 'only', 'christian', 'religion', 'is', 'followers', 'supporters', 'only', 'celebrated', 'by', 'but', 'this', 'all', 'world', 'in', 'before', 'all', 'religions', 'and', 'communities', "'s", 'people', 'celebrate', 'it', 'In this', 'way', 'without', 'discrimination', 'in', 'whole', 'world', 'in', 'celebrated', 'is', 'is', 'this', 'without', 'any'))),
#              ('b100-54920',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है', 'आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है', 'आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done', 'half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done', 'half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done'))),
#              ('b100-32087',
#               Sentence(words=('भैरव', 'का ', 'स्थान ', 'उत्तराखंड ', 'में ', 'क्षेत्रपाल ', 'अथवा ', 'भूमिदेव ', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'भैरव', 'का ', 'स्थान ', 'उत्तराखंड ', 'में ', 'क्षेत्रपाल ', 'अथवा ', 'भूमिदेव ', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'भैरव', 'का ', 'स्थान ', 'उत्तराखंड ', 'में ', 'क्षेत्रपाल ', 'अथवा ', 'भूमिदेव ', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मेल ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('Bhairav', 'is', 'place', 'Uttarakhand', 'as', 'Kshetrapal', 'or', 'Bhoomidev', 'is', 'way', 'as', 'important', 'is', 'Bhairav', 'is', 'place', 'Uttarakhand', 'as', 'Kshetrapal', 'or', 'Bhoomidev', 'is', 'way', 'as', 'important', 'is', 'Bhairav', 'is', 'place', 'Uttarakhand', 'as', 'Kshetrapal', 'or', 'Bhoomidev', 'is', 'way', 'as', 'important', 'is', 'All', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'reconciliation', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'all', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-30402',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-17866',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मेल ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है', 'इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'All', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'reconciliation', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'all', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it', 'Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said'))),
#              ('आतंकवाद\tTerrorism',
#               Sentence(words=('एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है', 'क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मेल ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has', 'Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'All', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'reconciliation', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'all', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('इराक  \tIraq',
#               Sentence(words=('के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है', 'क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है'), tags=('for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has', 'Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is')))])

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        sentences = read_data(datafile)
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %%
data = Dataset("english2.txt", "hindi2.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 18 sentences in the corpus.
# There are 14 sentences in the training set.
# There are 4 sentences in the testing set.

# %%
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है')
#
# Labels 1: ('Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is')
#
# Sentence 2: ('इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'आधा', 'किमी ', 'की ', 'दूरी ', 'पर ', 'भैरवनाथ ', 'मंदिर ', 'जहाँ ', 'केवल ', 'केदारनाथ ', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजन ', 'किया ', 'जाता ', 'है')
#
# Labels 2: ('Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'half', 'km', 'a', 'distance', 'at', 'Bhairavnath', 'temple', 'where', 'only', 'Kedarnath', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'worship', 'done', 'is', 'done')

# %%
key = 'b100-5507'
print("Sentence: {}".format(key))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: b100-87000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-35d41bec00e7> in <module>
#       1 key = 'b100-87000'
#       2 print("Sentence: {}".format(key))
# ----> 3 print("words:\n\t{!s}".format(data.sentences[key].words))
#       4 print("tags:\n\t{!s}".format(data.sentences[key].tags))
#
# KeyError: 'b100-87000'

# %%
words = [word for i, (word, tag) in enumerate(data.training_set.stream())]
tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
words[0:4], tags[0:4]
# Out:
# (['सभी ', 'पर्व ', 'ओर ', 'त्योहार '], ['All', 'festivals', 'and', 'festival'])

# %%
def pair_counts(tags, words):
    d = defaultdict(lambda: defaultdict(int))
    for tag, word in zip(tags, words):
        d[tag][word] += 1
    return d
        
word_counts = pair_counts(words, tags)

# %%
mfc_table = dict((word, max(tags.keys(), key=lambda key: tags[key])) for word, tags in word_counts.items())

# %%
i = 0
for key, value in mfc_table.items():
    print(key, value)
    i += 1
    if i > 3: break
# Out:
# यो this
# तो is
# ईसामसीह Jesus Christ
# के 's

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
# Using Most frequent POS tag
mfc_model = MFCTagger(mfc_table)

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %%
for key in data.testing_set.keys[:2]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-76546
#
# Sentence: ('क्रिसमस', 'का', 'पर्व', 'या', 'त्योहार-पर्व', 'है', 'जिसे', 'न', 'केवल', 'ईसाई', 'धर्म', 'के', 'अनुयायी', 'समर्थक', 'ही', 'मनाते', 'है', 'अपितु', 'इसे', 'टी', 'विशव', 'के', 'प्रायः', 'सभी', 'धर्मो', 'ओर', 'सम्प्रदाय', 'के', 'लोग', 'मनाते', 'है')
#
# Predicted labels:
# -----------------
# ['Christmas', "'s", 'festival', 'or', 'festival', 'is', 'that', 'is not', 'only', 'christian', 'religion', "'s", 'followers', 'supporters', 'only', 'celebrated', 'is', 'but', 'this', 'all', 'world', "'s", 'before', 'all', 'religions', 'and', 'communities', "'s", 'people', 'celebrated', 'is']
#
# Actual labels:
# --------------
# ('Christmas', "'s", 'festival', 'or', 'festival', 'is', 'that', 'is not', 'only', 'christian', 'religion', 'is', 'followers', 'supporters', 'only', 'celebrated', 'by', 'but', 'this', 'all', 'world', 'in', 'before', 'all', 'religions', 'and', 'communities', "'s", 'people', 'celebrate', 'it')
#
#
# Sentence Key: b100-76560
#
# Sentence: ('यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है')
#
# Predicted labels:
# -----------------
# ['it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'is', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'is']
#
# Actual labels:
# --------------
# ('it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it')

# %%
def accuracy(X, Y, model):
    
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# training accuracy mfc_model: 91.03%
# testing accuracy mfc_model: 82.87%

# %%
def unigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)
tag_unigrams
# Out:
# Counter({'this': 19,
#          'is': 38,
#          'Jesus Christ': 5,
#          "'s": 32,
#          'subject': 5,
#          'in': 34,
#          'different': 5,
#          'opinion': 5,
#          'that': 13,
#          'his': 5,
#          'birth': 5,
#          '25': 5,
#          'december': 5,
#          'night': 5,
#          'at': 5,
#          '12': 5,
#          "o'clock": 5,
#          'bethlum': 5,
#          'city': 5,
#          'one': 6,
#          'cowshed': 5,
#          'happened': 10,
#          'angels': 5,
#          'message': 6,
#          'through': 5,
#          'people': 11,
#          'has': 6,
#          'great man': 5,
#          'face': 5,
#          'accepted': 5,
#          'as': 9,
#          'a': 5,
#          'Apart': 2,
#          'from this': 2,
#          'Guggul': 2,
#          'Kund': 2,
#          'Bhima': 2,
#          'Cave': 2,
#          'and': 11,
#          'Bhimshila': 2,
#          'also worth': 2,
#          'visiting': 2,
#          'Christmas': 6,
#          'festival': 15,
#          'or': 11,
#          'is not': 6,
#          'only': 13,
#          'christian': 6,
#          'religion': 6,
#          'followers': 6,
#          'supporters': 6,
#          'celebrated': 9,
#          'by': 6,
#          'but': 7,
#          'all': 13,
#          'world': 10,
#          'before': 6,
#          'religions': 6,
#          'communities': 6,
#          'celebrate': 6,
#          'it': 13,
#          'In this': 3,
#          'way': 5,
#          'without': 6,
#          'discrimination': 3,
#          'whole': 4,
#          'any': 5,
#          'terrorism': 1,
#          'problem': 1,
#          'which': 1,
#          'not': 1,
#          'India': 1,
#          'for': 6,
#          'our': 1,
#          'engulfed': 1,
#          'take': 1,
#          'kept': 1,
#          'Iraq': 1,
#          'foreign': 2,
#          'minister': 1,
#          'America': 2,
#          'proposal': 1,
#          'mock': 1,
#          'made': 1,
#          'United': 1,
#          'Nations': 1,
#          'sanctions': 1,
#          "Iraq's": 1,
#          "citizen's": 1,
#          'them': 2,
#          'less': 1,
#          'harmful': 1,
#          'make': 1,
#          'said': 1,
#          'worth': 1,
#          'noting': 2,
#          'That': 1,
#          'indigenous': 1,
#          'be': 5,
#          'poor': 1,
#          'rich': 1,
#          'class': 1,
#          'whether': 1,
#          'above': 1,
#          'characteristic': 1,
#          'superiority': 1,
#          'must': 1,
#          'have': 1,
#          'Bhairav': 2,
#          'place': 2,
#          'Uttarakhand': 2,
#          'Kshetrapal': 2,
#          'Bhoomidev': 2,
#          'important': 2,
#          'All': 1,
#          'festivals': 3,
#          'mutual': 2,
#          'love': 1,
#          'brotherhood': 1,
#          'reconciliation': 1,
#          'meet': 1,
#          'gives': 2,
#          'does': 2,
#          'other': 1,
#          'words': 1,
#          'get': 2,
#          'we': 1,
#          'virtue': 1,
#          'sympathy': 1,
#          'cooperation': 1,
#          'humanity': 1,
#          'sense': 1})

# %%
def bigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
o = [(tags[i],tags[i+1]) for i in range(0,len(tags)-2,2)]
tag_bigrams = bigram_counts(o)
tag_bigrams
# Out:
# Counter({('this', 'is'): 3,
#          ('Jesus Christ', "'s"): 3,
#          ('subject', 'in'): 3,
#          ('different', 'opinion'): 3,
#          ('is', 'that'): 7,
#          ('his', 'birth'): 3,
#          ('25', 'december'): 3,
#          ("'s", 'night'): 3,
#          ('at', '12'): 3,
#          ("o'clock", 'bethlum'): 3,
#          ('city', 'in'): 3,
#          ('one', 'cowshed'): 3,
#          ('in', 'happened'): 3,
#          ('happened', 'angels'): 3,
#          ("'s", 'message'): 3,
#          ('through', 'people'): 3,
#          ('has', 'this'): 3,
#          ('great man', "'s"): 3,
#          ('face', 'in'): 3,
#          ('accepted', 'as'): 3,
#          ('a', 'In this'): 2,
#          ('way', 'without'): 3,
#          ('discrimination', 'in'): 3,
#          ('whole', 'world'): 4,
#          ('in', 'celebrated'): 3,
#          ('is', 'is'): 3,
#          ('this', 'without'): 3,
#          ('any', 'Christmas'): 2,
#          ("'s", 'festival'): 4,
#          ('or', 'festival'): 4,
#          ('is not', 'only'): 4,
#          ('christian', 'religion'): 4,
#          ('is', 'followers'): 4,
#          ('supporters', 'only'): 4,
#          ('celebrated', 'by'): 4,
#          ('but', 'this'): 4,
#          ('all', 'world'): 4,
#          ('in', 'before'): 4,
#          ('all', 'religions'): 4,
#          ('and', 'communities'): 4,
#          ("'s", 'people'): 4,
#          ('celebrate', 'it'): 4,
#          ('Apart', 'from this'): 2,
#          ('Guggul', 'Kund'): 2,
#          ('Bhima', 'Cave'): 2,
#          ('and', 'Bhimshila'): 2,
#          ('also worth', 'visiting'): 2,
#          ('is', 'half'): 1,
#          ('km', 'a'): 1,
#          ('distance', 'at'): 1,
#          ('Bhairavnath', 'temple'): 1,
#          ('where', 'only'): 1,
#          ('Kedarnath', 'is'): 1,
#          ('door', 'opening'): 1,
#          ('and', 'closing'): 1,
#          ('done', 'is'): 1,
#          ('day', 'only'): 1,
#          ('worship', 'done'): 1,
#          ('is', 'done'): 1,
#          ('any', 'this'): 1,
#          ('is', 'Jesus Christ'): 3,
#          ("'s", 'subject'): 3,
#          ('in', 'different'): 3,
#          ('opinion', 'is'): 3,
#          ('that', 'his'): 3,
#          ('birth', '25'): 3,
#          ('december', "'s"): 3,
#          ('night', 'at'): 3,
#          ('12', "o'clock"): 3,
#          ('bethlum', 'city'): 3,
#          ('in', 'one'): 3,
#          ('cowshed', 'in'): 3,
#          ('happened', 'happened'): 3,
#          ('angels', "'s"): 3,
#          ('message', 'through'): 3,
#          ('people', 'has'): 3,
#          ('this', 'great man'): 3,
#          ("'s", 'face'): 3,
#          ('in', 'accepted'): 3,
#          ('as', 'a'): 2,
#          ('Bhairav', 'is'): 2,
#          ('place', 'Uttarakhand'): 2,
#          ('as', 'Kshetrapal'): 2,
#          ('or', 'Bhoomidev'): 2,
#          ('is', 'way'): 2,
#          ('as', 'important'): 2,
#          ('is', 'All'): 1,
#          ('festivals', 'and'): 1,
#          ('festival', 'mutual'): 1,
#          ('love', 'brotherhood'): 1,
#          ('reconciliation', 'meet'): 1,
#          ('message', 'gives'): 1,
#          ('does', 'other'): 1,
#          ('words', 'in'): 1,
#          ('all', 'festivals'): 1,
#          ('festivals', 'get'): 1,
#          ('we', 'virtue'): 1,
#          ('sympathy', 'mutual'): 1,
#          ('cooperation', 'and'): 1,
#          ('humanity', 'it'): 1,
#          ('sense', 'gives'): 1,
#          ('get', 'does'): 1,
#          ('is', 'it'): 2,
#          ('worth', 'noting'): 3,
#          ('is', 'noting'): 3,
#          ('is', 'That'): 3,
#          ('any', 'any'): 3,
#          ('festival', 'or'): 6,
#          ('festival', 'it'): 3,
#          ('indigenous', 'be'): 3,
#          ('or', 'foreign'): 3,
#          ('be', 'it'): 6,
#          ('poor', 'be'): 3,
#          ('or', 'rich'): 3,
#          ('class', 'it'): 3,
#          ('be', 'whether'): 3,
#          ('above', 'characteristic'): 3,
#          ('and', 'superiority'): 3,
#          ('must', 'have'): 3,
#          ('it', 'Christmas'): 2,
#          ('a', 'Iraq'): 1,
#          ('for', 'foreign'): 1,
#          ('minister', 'America'): 1,
#          ('for', 'that'): 1,
#          ('proposal', 'mock'): 1,
#          ('made', 'in'): 1,
#          ('America', 'United'): 1,
#          ('Nations', 'for'): 1,
#          ('sanctions', "Iraq's"): 1,
#          ("citizen's", 'for'): 1,
#          ('them', 'less'): 1,
#          ('harmful', 'make'): 1,
#          ('for', 'them'): 1,
#          ('said', 'terrorism'): 1,
#          ('one', 'that'): 1,
#          ('problem', 'which'): 1,
#          ('not', 'only'): 1,
#          ('India', 'but'): 1,
#          ('for', 'our'): 1,
#          ('engulfed', 'take'): 1,
#          ('kept', 'has'): 1,
#          ('In this', 'way'): 1,
#          ('without', 'discrimination'): 1,
#          ('in', 'whole'): 1,
#          ('world', 'in'): 4,
#          ('celebrated', 'is'): 1,
#          ('is', 'this'): 1,
#          ('without', 'any'): 1,
#          ('Christmas', "'s"): 3,
#          ('festival', 'is'): 3,
#          ('that', 'is not'): 3,
#          ('only', 'christian'): 3,
#          ('religion', 'is'): 3,
#          ('followers', 'supporters'): 3,
#          ('only', 'celebrated'): 3,
#          ('by', 'but'): 3,
#          ('this', 'all'): 3,
#          ('before', 'all'): 3,
#          ('religions', 'and'): 3,
#          ('communities', "'s"): 3,
#          ('people', 'celebrate'): 3,
#          ('it', 'it'): 1,
#          ('it', 'this'): 2,
#          ('it', 'In this'): 1})

# %%
def starting_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
starts_tag = [i[0] for i in data.Y]
tag_starts = starting_counts(starts_tag)
tag_starts
# Out:
# Counter({'this': 6,
#          'In this': 4,
#          'Christmas': 7,
#          'Apart': 2,
#          'half': 1,
#          'Bhairav': 2,
#          'All': 1,
#          'it': 3,
#          'Iraq': 1,
#          'terrorism': 1})

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'a': 6,
#          'any': 4,
#          'it': 10,
#          'is': 4,
#          'done': 1,
#          'does': 1,
#          'said': 1,
#          'has': 1})

# %%
end_tag = [i[len(i)-2] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'as': 6,
#          'without': 4,
#          'celebrate': 7,
#          'visiting': 2,
#          'is': 1,
#          'important': 2,
#          'get': 1,
#          'have': 3,
#          'them': 1,
#          'kept': 1})

# %%
hmm_model = HiddenMarkovModel(name="base-hmm-tagger")

tags = [tag for i, (word, tag) in enumerate(data.stream())]
words = [word for i, (word, tag) in enumerate(data.stream())]

tags_count = unigram_counts(tags)
tag_words_count = pair_counts(tags, words)

starting_tag_list = [i[0] for i in data.Y]
#ending_tag_list = [i[-1] if len(i)==1 else i[-2] for i in data.Y]
#ending_tag_list = [i[-1] for i in data.Y]
ending_tag_list = [i[len(i)-1] for i in data.Y]

starting_tag_count = starting_counts(starting_tag_list) #the number of times a tag occured at the start
ending_tag_count = ending_counts(ending_tag_list)       #the number of times a tag occured at the end

tag_words_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'this': defaultdict(int, {'यो': 6, 'इन्हें': 6, 'इसे': 11}),
#              'is': defaultdict(int,
#                          {'तो': 6,
#                           'है': 21,
#                           'जाता': 4,
#                           'के': 7,
#                           'के ': 4,
#                           'जाता ': 1,
#                           'का ': 2,
#                           'की ': 3,
#                           'हैं': 3}),
#              'Jesus Christ': defaultdict(int, {'ईसामसीह': 6}),
#              "'s": defaultdict(int, {'के': 25, 'की': 6, 'का': 7}),
#              'subject': defaultdict(int, {'विषय': 6}),
#              'in': defaultdict(int,
#                          {'मे': 6,
#                           'की': 6,
#                           'में': 16,
#                           'के': 11,
#                           'में ': 1,
#                           'जिसमें': 1}),
#              'different': defaultdict(int, {'अनेक': 6}),
#              'opinion': defaultdict(int, {'लोकमत': 6}),
#              'that': defaultdict(int, {'कि': 6, 'जिसे': 7, 'उस': 1, 'ऐसी': 1}),
#              'his': defaultdict(int, {'उनका': 6}),
#              'birth': defaultdict(int, {'जन्म': 6}),
#              '25': defaultdict(int, {'25': 6}),
#              'december': defaultdict(int, {'दिसम्बर': 6}),
#              'night': defaultdict(int, {'रात': 6}),
#              'at': defaultdict(int, {'को': 6, 'पर ': 1}),
#              '12': defaultdict(int, {'12': 6}),
#              "o'clock": defaultdict(int, {'बजे': 6}),
#              'bethlum': defaultdict(int, {'बेथलम': 6}),
#              'city': defaultdict(int, {'शहर': 6}),
#              'one': defaultdict(int, {'एक': 7}),
#              'cowshed': defaultdict(int, {'गौशाला': 6}),
#              'happened': defaultdict(int, {'हुआ': 6, 'था': 6}),
#              'angels': defaultdict(int, {'देवदूतों': 6}),
#              'message': defaultdict(int, {'संदेश': 6, 'संदेश ': 1}),
#              'through': defaultdict(int, {'से': 6}),
#              'people': defaultdict(int, {'लोगों': 6, 'लोग': 7}),
#              'has': defaultdict(int, {'ने': 6, 'है': 1}),
#              'great man': defaultdict(int, {'महापुरुष': 6}),
#              'face': defaultdict(int, {'रूप': 6}),
#              'accepted': defaultdict(int, {'स्वीकार': 6}),
#              'as': defaultdict(int, {'कर': 6, 'में ': 4}),
#              'a': defaultdict(int, {'लिया': 6, 'की ': 1}),
#              'In this': defaultdict(int, {'इस': 4}),
#              'way': defaultdict(int, {'प्रकार': 4, 'रूप ': 2}),
#              'without': defaultdict(int, {'बिना': 8}),
#              'discrimination': defaultdict(int, {'भेदभाव': 4}),
#              'whole': defaultdict(int, {'पूरे': 5}),
#              'world': defaultdict(int, {'विशव': 11, 'विश्व': 1}),
#              'celebrated': defaultdict(int, {'मनाया': 4, 'मनाते': 7}),
#              'any': defaultdict(int, {'कोई': 4, 'कोई ': 3, 'भी ': 3}),
#              'Christmas': defaultdict(int, {'क्रिसमस': 7}),
#              'festival': defaultdict(int,
#                          {'पर्व': 10, 'त्योहार-पर्व': 7, 'त्योहार ': 4}),
#              'or': defaultdict(int, {'या': 7, 'अथवा ': 2, 'या ': 9}),
#              'is not': defaultdict(int, {'न': 7}),
#              'only': defaultdict(int,
#                          {'केवल': 8, 'ही': 7, 'केवल ': 1, 'ही ': 1}),
#              'christian': defaultdict(int, {'ईसाई': 7}),
#              'religion': defaultdict(int, {'धर्म': 7}),
#              'followers': defaultdict(int, {'अनुयायी': 7}),
#              'supporters': defaultdict(int, {'समर्थक': 7}),
#              'by': defaultdict(int, {'है': 7}),
#              'but': defaultdict(int, {'अपितु': 8}),
#              'all': defaultdict(int, {'टी': 7, 'सभी': 7, 'सभी ': 1}),
#              'before': defaultdict(int, {'प्रायः': 7}),
#              'religions': defaultdict(int, {'धर्मो': 7}),
#              'and': defaultdict(int, {'ओर': 7, 'तथा': 2, 'और ': 2, 'ओर ': 4}),
#              'communities': defaultdict(int, {'सम्प्रदाय': 7}),
#              'celebrate': defaultdict(int, {'मनाते': 7}),
#              'it': defaultdict(int,
#                          {'है': 10,
#                           'की ': 1,
#                           'यह ': 3,
#                           'चाहे ': 6,
#                           'का ': 3,
#                           'उसमे ': 3}),
#              'Apart': defaultdict(int, {'इसके   ': 2}),
#              'from this': defaultdict(int, {'अतिरिक्त': 2}),
#              'Guggul': defaultdict(int, {'गुग्गुल': 2}),
#              'Kund': defaultdict(int, {'कुंड': 2}),
#              'Bhima': defaultdict(int, {'भीम': 2}),
#              'Cave': defaultdict(int, {'गुफा ': 2}),
#              'Bhimshila': defaultdict(int, {'भीमशिला': 2}),
#              'also worth': defaultdict(int, {'भी': 2}),
#              'visiting': defaultdict(int, {'दर्शनीय': 2}),
#              'half': defaultdict(int, {'आधा': 1}),
#              'km': defaultdict(int, {'किमी ': 1}),
#              'distance': defaultdict(int, {'दूरी ': 1}),
#              'Bhairavnath': defaultdict(int, {'भैरवनाथ ': 1}),
#              'temple': defaultdict(int, {'मंदिर ': 1}),
#              'where': defaultdict(int, {'जहाँ ': 1}),
#              'Kedarnath': defaultdict(int, {'केदारनाथ ': 1}),
#              'door': defaultdict(int, {'पट ': 1}),
#              'opening': defaultdict(int, {'खुलने ': 1}),
#              'closing': defaultdict(int, {'बंद ': 1}),
#              'done': defaultdict(int, {'होने ': 1, 'किया ': 1, 'है': 1}),
#              'day': defaultdict(int, {'दिन ': 1}),
#              'worship': defaultdict(int, {'पूजन ': 1}),
#              'Bhairav': defaultdict(int, {'भैरव': 2}),
#              'place': defaultdict(int, {'स्थान ': 2}),
#              'Uttarakhand': defaultdict(int, {'उत्तराखंड ': 2}),
#              'Kshetrapal': defaultdict(int, {'क्षेत्रपाल ': 2}),
#              'Bhoomidev': defaultdict(int, {'भूमिदेव ': 2}),
#              'important': defaultdict(int, {'महत्वपूर्ण ': 2}),
#              'All': defaultdict(int, {'सभी ': 1}),
#              'festivals': defaultdict(int,
#                          {'पर्व ': 1, 'पर्वो  ': 1, 'त्योहार': 1}),
#              'mutual': defaultdict(int, {'परस्पर ': 2}),
#              'love': defaultdict(int, {'प्रेम ': 1}),
#              'brotherhood': defaultdict(int, {'भाईचारा ': 1}),
#              'reconciliation': defaultdict(int, {'मेल ': 1}),
#              'meet': defaultdict(int, {'मिलाप ': 1}),
#              'gives': defaultdict(int, {'देता ': 1, 'प्राप्त ': 1}),
#              'does': defaultdict(int, {'हे ': 1, 'है': 1}),
#              'other': defaultdict(int, {'दूसरे ': 1}),
#              'words': defaultdict(int, {'शब्दों ': 1}),
#              'get': defaultdict(int, {'से ': 1, 'होती ': 1}),
#              'we': defaultdict(int, {'हमे ': 1}),
#              'virtue': defaultdict(int, {'सदाचार  ': 1}),
#              'sympathy': defaultdict(int, {'सहानुभूति ': 1}),
#              'cooperation': defaultdict(int, {'सहयोग ': 1}),
#              'humanity': defaultdict(int, {'मानवता ': 1}),
#              'sense': defaultdict(int, {'भावना ': 1}),
#              'worth': defaultdict(int, {'ध्यान ': 3}),
#              'noting': defaultdict(int, {'देने ': 3, 'बात ': 3}),
#              'That': defaultdict(int, {'कि ': 3}),
#              'indigenous': defaultdict(int, {'स्वदेशी ': 3}),
#              'be': defaultdict(int, {'हो ': 9, 'हो': 3, 'क्यों ': 3}),
#              'foreign': defaultdict(int, {'विदेशी ': 3, 'विदेश': 1}),
#              'poor': defaultdict(int, {'गरीब ': 3}),
#              'rich': defaultdict(int, {'अमीर ': 3}),
#              'class': defaultdict(int, {'वर्ग ': 3}),
#              'whether': defaultdict(int, {'ना ': 3}),
#              'above': defaultdict(int, {'उपर्युक्त ': 3}),
#              'characteristic': defaultdict(int, {'विशेषता ': 3}),
#              'superiority': defaultdict(int, {'श्रेष्ठता ': 3}),
#              'must': defaultdict(int, {'अवश्य ': 3}),
#              'have': defaultdict(int, {'होती ': 3}),
#              'Iraq': defaultdict(int, {'इराक  ': 1}),
#              'for': defaultdict(int, {'के': 5, 'को': 1}),
#              'minister': defaultdict(int, {'मंत्री': 1}),
#              'America': defaultdict(int, {'अमरीका': 2}),
#              'proposal': defaultdict(int, {'प्रस्ताव': 1}),
#              'mock': defaultdict(int, {'मजाक': 1}),
#              'made': defaultdict(int, {'उड़ाया': 1}),
#              'United': defaultdict(int, {'संयुक्त': 1}),
#              'Nations': defaultdict(int, {'राष्ट्र': 1}),
#              'sanctions': defaultdict(int, {'प्रतिबंधों': 1}),
#              "Iraq's": defaultdict(int, {'इराकी': 1}),
#              "citizen's": defaultdict(int, {'नागरिकों': 1}),
#              'them': defaultdict(int, {'लिए': 2}),
#              'less': defaultdict(int, {'कम': 1}),
#              'harmful': defaultdict(int, {'हानिकारक': 1}),
#              'make': defaultdict(int, {'बनाने': 1}),
#              'said': defaultdict(int, {'कहा': 1}),
#              'terrorism': defaultdict(int, {'आतंकवाद': 1}),
#              'problem': defaultdict(int, {'समस्या': 1}),
#              'which': defaultdict(int, {'जिसने': 1}),
#              'not': defaultdict(int, {'न': 1}),
#              'India': defaultdict(int, {'भारत': 1}),
#              'our': defaultdict(int, {'अपने': 1}),
#              'engulfed': defaultdict(int, {'लपेटे': 1}),
#              'take': defaultdict(int, {'ले': 1}),
#              'kept': defaultdict(int, {'रखा': 1})})

# %%
to_pass_states = []
for tag, words_dict in tag_words_count.items():
    total = float(sum(words_dict.values()))
    distribution = {word: count/total for word, count in words_dict.items()}
    tag_emissions = DiscreteDistribution(distribution)
    tag_state = State(tag_emissions, name=tag)
    to_pass_states.append(tag_state)

# %%
distribution
# Out:
# {'रखा': 1.0}

# %%
to_pass_states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092f\u094b" : 0.2608695652173913,
#                  "\u0907\u0928\u094d\u0939\u0947\u0902" : 0.2608695652173913,
#                  "\u0907\u0938\u0947" : 0.4782608695652174
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u094b" : 0.11764705882352941,
#                  "\u0939\u0948" : 0.4117647058823529,
#                  "\u091c\u093e\u0924\u093e" : 0.0784313725490196,
#                  "\u0915\u0947" : 0.13725490196078433,
#                  "\u0915\u0947 " : 0.0784313725490196,
#                  "\u091c\u093e\u0924\u093e " : 0.0196078431372549,
#                  "\u0915\u093e " : 0.0392156862745098,
#                  "\u0915\u0940 " : 0.058823529411764705,
#                  "\u0939\u0948\u0902" : 0.058823529411764705
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "is",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0908\u0938\u093e\u092e\u0938\u0940\u0939" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Jesus Christ",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947" : 0.6578947368421053,
#                  "\u0915\u0940" : 0.15789473684210525,
#                  "\u0915\u093e" : 0.18421052631578946
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "'s",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0937\u092f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "subject",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0947" : 0.14634146341463414,
#                  "\u0915\u0940" : 0.14634146341463414,
#                  "\u092e\u0947\u0902" : 0.3902439024390244,
#                  "\u0915\u0947" : 0.2682926829268293,
#                  "\u092e\u0947\u0902 " : 0.024390243902439025,
#                  "\u091c\u093f\u0938\u092e\u0947\u0902" : 0.024390243902439025
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "in",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0928\u0947\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "different",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u094b\u0915\u092e\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "opinion",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u093f" : 0.4,
#                  "\u091c\u093f\u0938\u0947" : 0.4666666666666667,
#                  "\u0909\u0938" : 0.06666666666666667,
#                  "\u0910\u0938\u0940" : 0.06666666666666667
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "that",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0928\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "his",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u0928\u094d\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "birth",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "25" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "25",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093f\u0938\u092e\u094d\u092c\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "december",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u093e\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "night",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b" : 0.8571428571428571,
#                  "\u092a\u0930 " : 0.14285714285714285
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "at",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "12" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "12",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u091c\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "o'clock",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0947\u0925\u0932\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bethlum",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u0939\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "city",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u090f\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "one",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u094c\u0936\u093e\u0932\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "cowshed",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0941\u0906" : 0.5,
#                  "\u0925\u093e" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "happened",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0935\u0926\u0942\u0924\u094b\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "angels",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0902\u0926\u0947\u0936" : 0.8571428571428571,
#                  "\u0938\u0902\u0926\u0947\u0936 " : 0.14285714285714285
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "message",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "through",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u094b\u0917\u094b\u0902" : 0.46153846153846156,
#                  "\u0932\u094b\u0917" : 0.5384615384615384
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "people",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u0947" : 0.8571428571428571,
#                  "\u0939\u0948" : 0.14285714285714285
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "has",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0939\u093e\u092a\u0941\u0930\u0941\u0937" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "great man",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u0942\u092a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "face",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u094d\u0935\u0940\u0915\u093e\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "accepted",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930" : 0.6,
#                  "\u092e\u0947\u0902 " : 0.4
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "as",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u093f\u092f\u093e" : 0.8571428571428571,
#                  "\u0915\u0940 " : 0.14285714285714285
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "a",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0938" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "In this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u0915\u093e\u0930" : 0.6666666666666666,
#                  "\u0930\u0942\u092a " : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "way",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u093f\u0928\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "without",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0947\u0926\u092d\u093e\u0935" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "discrimination",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0942\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "whole",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0936\u0935" : 0.9166666666666666,
#                  "\u0935\u093f\u0936\u094d\u0935" : 0.08333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "world",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0928\u093e\u092f\u093e" : 0.36363636363636365,
#                  "\u092e\u0928\u093e\u0924\u0947" : 0.6363636363636364
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "celebrated",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b\u0908" : 0.4,
#                  "\u0915\u094b\u0908 " : 0.3,
#                  "\u092d\u0940 " : 0.3
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "any",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094d\u0930\u093f\u0938\u092e\u0938" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Christmas",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930\u094d\u0935" : 0.47619047619047616,
#                  "\u0924\u094d\u092f\u094b\u0939\u093e\u0930-\u092a\u0930\u094d\u0935" : 0.3333333333333333,
#                  "\u0924\u094d\u092f\u094b\u0939\u093e\u0930 " : 0.19047619047619047
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "festival",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092f\u093e" : 0.3888888888888889,
#                  "\u0905\u0925\u0935\u093e " : 0.1111111111111111,
#                  "\u092f\u093e " : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "or",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "is not",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947\u0935\u0932" : 0.47058823529411764,
#                  "\u0939\u0940" : 0.4117647058823529,
#                  "\u0915\u0947\u0935\u0932 " : 0.058823529411764705,
#                  "\u0939\u0940 " : 0.058823529411764705
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "only",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0908\u0938\u093e\u0908" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "christian",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0927\u0930\u094d\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "religion",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0928\u0941\u092f\u093e\u092f\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "followers",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u0930\u094d\u0925\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "supporters",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0948" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "by",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092a\u093f\u0924\u0941" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "but",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091f\u0940" : 0.4666666666666667,
#                  "\u0938\u092d\u0940" : 0.4666666666666667,
#                  "\u0938\u092d\u0940 " : 0.06666666666666667
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "all",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u093e\u092f\u0903" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "before",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0927\u0930\u094d\u092e\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "religions",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0913\u0930" : 0.4666666666666667,
#                  "\u0924\u0925\u093e" : 0.13333333333333333,
#                  "\u0914\u0930 " : 0.13333333333333333,
#                  "\u0913\u0930 " : 0.26666666666666666
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "and",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u094d\u092a\u094d\u0930\u0926\u093e\u092f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "communities",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0928\u093e\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "celebrate",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0948" : 0.38461538461538464,
#                  "\u0915\u0940 " : 0.038461538461538464,
#                  "\u092f\u0939 " : 0.11538461538461539,
#                  "\u091a\u093e\u0939\u0947 " : 0.23076923076923078,
#                  "\u0915\u093e " : 0.11538461538461539,
#                  "\u0909\u0938\u092e\u0947 " : 0.11538461538461539
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "it",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0938\u0915\u0947   " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Apart",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0924\u093f\u0930\u093f\u0915\u094d\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "from this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0941\u0917\u094d\u0917\u0941\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Guggul",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0941\u0902\u0921" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Kund",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0940\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Bhima",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0941\u092b\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Cave",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0940\u092e\u0936\u093f\u0932\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Bhimshila",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "also worth",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0930\u094d\u0936\u0928\u0940\u092f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "visiting",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0906\u0927\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "half",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u093f\u092e\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "km",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0942\u0930\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "distance",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0948\u0930\u0935\u0928\u093e\u0925 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Bhairavnath",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0902\u0926\u093f\u0930 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "temple",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u0939\u093e\u0901 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "where",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947\u0926\u093e\u0930\u0928\u093e\u0925 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Kedarnath",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u091f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "door",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0941\u0932\u0928\u0947 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "opening",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0902\u0926 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "closing",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u094b\u0928\u0947 " : 0.3333333333333333,
#                  "\u0915\u093f\u092f\u093e " : 0.3333333333333333,
#                  "\u0939\u0948" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "done",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093f\u0928 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "day",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0942\u091c\u0928 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "worship",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0948\u0930\u0935" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Bhairav",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u094d\u0925\u093e\u0928 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "place",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0924\u094d\u0924\u0930\u093e\u0916\u0902\u0921 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Uttarakhand",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094d\u0937\u0947\u0924\u094d\u0930\u092a\u093e\u0932 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Kshetrapal",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0942\u092e\u093f\u0926\u0947\u0935 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Bhoomidev",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0939\u0924\u094d\u0935\u092a\u0942\u0930\u094d\u0923 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "important",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092d\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "All",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930\u094d\u0935 " : 0.3333333333333333,
#                  "\u092a\u0930\u094d\u0935\u094b  " : 0.3333333333333333,
#                  "\u0924\u094d\u092f\u094b\u0939\u093e\u0930" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "festivals",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930\u0938\u094d\u092a\u0930 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "mutual",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u0947\u092e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "love",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u093e\u0908\u091a\u093e\u0930\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "brotherhood",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0947\u0932 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "reconciliation",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093f\u0932\u093e\u092a " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "meet",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0924\u093e " : 0.5,
#                  "\u092a\u094d\u0930\u093e\u092a\u094d\u0924 " : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "gives",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0947 " : 0.5,
#                  "\u0939\u0948" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "does",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0942\u0938\u0930\u0947 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "other",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u092c\u094d\u0926\u094b\u0902 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "words",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947 " : 0.5,
#                  "\u0939\u094b\u0924\u0940 " : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "get",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u092e\u0947 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "we",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0926\u093e\u091a\u093e\u0930  " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "virtue",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0939\u093e\u0928\u0941\u092d\u0942\u0924\u093f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sympathy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0939\u092f\u094b\u0917 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "cooperation",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093e\u0928\u0935\u0924\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "humanity",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u093e\u0935\u0928\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sense",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0927\u094d\u092f\u093e\u0928 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "worth",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0928\u0947 " : 0.5,
#                  "\u092c\u093e\u0924 " : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "noting",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u093f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "That",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u094d\u0935\u0926\u0947\u0936\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "indigenous",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u094b " : 0.6,
#                  "\u0939\u094b" : 0.2,
#                  "\u0915\u094d\u092f\u094b\u0902 " : 0.2
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "be",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0926\u0947\u0936\u0940 " : 0.75,
#                  "\u0935\u093f\u0926\u0947\u0936" : 0.25
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "foreign",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0930\u0940\u092c " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "poor",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092e\u0940\u0930 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "rich",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0930\u094d\u0917 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "class",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "whether",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u092a\u0930\u094d\u092f\u0941\u0915\u094d\u0924 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "above",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0936\u0947\u0937\u0924\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "characteristic",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u094d\u0930\u0947\u0937\u094d\u0920\u0924\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "superiority",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0935\u0936\u094d\u092f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "must",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u094b\u0924\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "have",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0930\u093e\u0915  " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Iraq",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947" : 0.8333333333333334,
#                  "\u0915\u094b" : 0.16666666666666666
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "for",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0902\u0924\u094d\u0930\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "minister",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092e\u0930\u0940\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "America",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u0938\u094d\u0924\u093e\u0935" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "proposal",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u091c\u093e\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "mock",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u095c\u093e\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "made",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0902\u092f\u0941\u0915\u094d\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "United",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u093e\u0937\u094d\u091f\u094d\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Nations",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u0924\u093f\u092c\u0902\u0927\u094b\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sanctions",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0930\u093e\u0915\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Iraq's",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u093e\u0917\u0930\u093f\u0915\u094b\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "citizen's",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u093f\u090f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "them",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "less",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u093e\u0928\u093f\u0915\u093e\u0930\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "harmful",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0928\u093e\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "make",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0939\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "said",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0906\u0924\u0902\u0915\u0935\u093e\u0926" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "terrorism",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u0938\u094d\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "problem",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u093f\u0938\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "which",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "not",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u093e\u0930\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "India",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092a\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "our",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u092a\u0947\u091f\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "engulfed",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "take",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u0916\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "kept",
#      "weight" : 1.0
#  }]

# %%
start_prob={}

for tag in tags:
    start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

for tag_state in to_pass_states :
    hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])

# %%
end_prob={}

for tag in tags:
    end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
for tag_state in to_pass_states :
    hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])

# %%
transition_prob_pair={}

for key in tag_bigrams.keys():
    transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
for tag_state in to_pass_states:
    for next_tag_state in to_pass_states:
        if((tag_state.name,next_tag_state.name) in transition_prob_pair):
            hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])

# %%
hmm_model.bake()

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, hmm_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, hmm_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))
# Out:
# training accuracy basic hmm model: 72.76%
# testing accuracy basic hmm model: 46.96%
